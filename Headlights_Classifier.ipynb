# %% [markdown]
# # The purpose of this notebook is to create a multilabel classifier where one can classify between headlights on/off/dimmed

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# List the contents of the specified folder
import os

folder_path = '/content/drive/MyDrive/visionrd_dataset/headlight_dataset-20250731T102207Z-1-001/headlight_dataset'

if os.path.exists(folder_path):
    print(f"Contents of '{folder_path}':")
    for item in os.listdir(folder_path):
        print(item)
else:
    print(f"Folder '{folder_path}' not found.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Contents of '/content/drive/MyDrive/visionrd_dataset/headlight_dataset-20250731T102207Z-1-001/headlight_dataset':
# test
# train

# %% [markdown]
# # Utilizing Pytorch in order to utilize a prebuilt classifier and fine tuning it

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import datasets

# %%
train_dataset = datasets.ImageFolder(folder_path+'/train')
test_dataset = datasets.ImageFolder(folder_path+'/test')

# %%
loaded_train_data = DataLoader(
    dataset=train_dataset,
    batch_size=5,
    shuffle=True
)

# %%
train_dataset.classes
# Out:
# ['OFF', 'ON_high', 'ON_low']

# %% [markdown]
# # go in the following link to get the tutorial
# [link text](https://docs.pytorch.org/tutorials/beginner/transfer_learning_tutorial.html#load-data)
